# %% [markdown]
# ### Create Data

# %%
import numpy
import matplotlib.pyplot as plt

import matplotlib as mpl

mpl.rcParams.update(
    {"font.size": 25, "text.color": "lavender", "font.family": "Palatino Linotype"}
)

numb_data_points = 25

y_1 = numpy.random.normal(28, 8, numb_data_points)  # undergrads
y_2 = numpy.random.normal(12, 5, numb_data_points)  # grad
y_3 = numpy.random.normal(5, 3, numb_data_points)  # non tunured faculty
y_4 = numpy.random.normal(18, 12, numb_data_points)  # tenured faculty

data = [y_1, y_2, y_3, y_4]

data_labels = [
    "Undergrad\nStudents",
    "Graduate\nStudents",
    "Non-Tenured\nFaculty",
    "Tenured\nFaculty",
]

title = "Alcoholic beverages consumed in the past month"

y_label = "Number of drinks"

scatter_size = 200

box_plot_width = 0.75
fig_size = [12, 10]

# mpl.font_manager.get_font_names()

# %% [markdown]
# ### Initial Plot

# %%
axs = plt.subplot()
axs.boxplot(x=data, labels=data_labels, widths=box_plot_width)
axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)

# %% [markdown]
# ### Improving Accessebility

# %%
# https://palett.es/2a2b3e-78501c-c2996d-bdaf83-bbc5aap
axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)


axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)

# %% [markdown]
# ### Add Raw data in form of scatter plot

# %%
import numpy as np

axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
    showfliers=False,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)

for idx, y_data in enumerate(data):
    x_values = np.ones(len(y_data)) * (idx + 1)

    axs.scatter(
        x_values,
        y_data,
        color=color_codes[idx],
        edgecolors="black",
        linewidths=1.75,
        s=scatter_size,
    )

axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)

# %%
import numpy as np

axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
    showfliers=False,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)

for idx, y_data in enumerate(data):
    x_values = np.ones(len(y_data)) * (idx + 1)

    axs.scatter(
        x_values,
        y_data,
        color=color_codes[idx],
        edgecolors="black",
        linewidths=1.75,
        s=scatter_size,
    )
plt.grid()
axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)

# %% [markdown]
# ### Controling Layers of plots

# %%
import numpy as np

axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
    showfliers=False,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)

for idx, y_data in enumerate(data):
    x_values = np.ones(len(y_data)) * (idx + 1)

    axs.scatter(
        x_values,
        y_data,
        color=color_codes[idx],
        edgecolors="black",
        linewidths=1.75,
        s=scatter_size,
        zorder=20,
    )
plt.grid()
axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)

# %% [markdown]
# ### Alpha values

# %%
import numpy as np

axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
    showfliers=False,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)

for idx, y_data in enumerate(data):
    x_values = np.ones(len(y_data)) * (idx + 1)

    axs.scatter(
        x_values,
        y_data,
        color=color_codes[idx],
        edgecolors="black",
        linewidths=1.75,
        s=scatter_size,
        zorder=20,
    )
plt.grid(alpha=0.5)
axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)

# %% [markdown]
# ### Jitter your scatter

# %%
import numpy as np

axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
    showfliers=False,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)

jitter_width = box_plot_width / 3

for idx, y_data in enumerate(data):
    x_values = np.ones(len(y_data)) * (idx + 1) + np.random.uniform(
        -jitter_width, jitter_width, len(y_data)
    )
    print(x_values)

    axs.scatter(
        x_values,
        y_data,
        color=color_codes[idx],
        edgecolors="black",
        linewidths=1.75,
        s=scatter_size,
        zorder=20,
    )

plt.grid(alpha=0.5)
axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)
# Out:
# [1.13143529 0.87047469 1.07343623 1.16831212 0.83366591 0.8417033
#  0.87443349 1.09250222 0.94357699 1.00859274 0.82824993 0.96128726
#  1.1641033  0.92264644 1.15170801 1.06183825 1.22703541 0.93173496
#  0.86493409 0.76379452 1.12480729 1.24415347 1.03806092 0.9226599
#  0.78802759]
# [2.11608169 1.87365756 2.13640681 1.79095662 1.9945325  1.76426698
#  1.83814499 2.11863921 2.20760988 1.80243972 1.87160021 2.12441338
#  1.85817747 1.80871292 2.19733264 2.05525038 2.1204792  1.80402857
#  1.91829974 1.75761167 2.17050474 1.91459415 2.18659543 2.07112246
#  2.19962694]
# [2.90435434 3.12023248 3.19286246 3.08945497 2.84929016 2.75346656
#  3.11474656 3.16005777 2.95987797 3.09117637 2.98773191 2.75336774
#  2.80998669 2.89972899 3.05844857 3.0992628  3.03401211 2.85357291
#  3.02797067 3.07126208 2.93335269 2.91546136 3.1779324  3.18763862
#  2.80678517]
# [3.95748534 3.77388198 4.16519905 4.18901002 3.96921053 4.1938603
#  3.84271028 3.80134454 4.18684317 3.81342811 3.95506577 4.01895743
#  3.87313518 4.01949625 3.96082814 3.8492467  3.9908657  4.24462552
#  4.17872742 3.81436288 4.21719128 4.0667079  3.86252507 3.75451499
#  4.08739056]

# %%
import numpy as np

axs = plt.subplot()

b_plot = plt.boxplot(
    x=data,
    labels=data_labels,
    widths=box_plot_width,
    patch_artist=True,
    showfliers=False,
)

color_codes = ["#376101", "#89ce00", "#e6308a", "#8f144e"]

for patch, color_code in zip(b_plot["boxes"], color_codes):
    patch.set_facecolor(color_code)

jitter_width = box_plot_width / 3

for idx, y_data in enumerate(data):
    x_values = np.ones(len(y_data)) * (idx + 1) + np.random.uniform(
        -jitter_width, jitter_width, len(y_data)
    )

    if idx == 3:
        for y_idx in range(len(y_data)):
            if y_data[y_idx] >= 13:
                split_marker = "D"
            else:
                split_marker = "o"

            axs.scatter(
                x_values[y_idx],
                y_data[y_idx],
                color=color_codes[idx],
                edgecolors="black",
                linewidths=1.75,
                s=scatter_size,
                zorder=20,
                marker=split_marker,
            )

    else:
        axs.scatter(
            x_values,
            y_data,
            color=color_codes[idx],
            edgecolors="black",
            linewidths=1.75,
            s=scatter_size,
            zorder=20,
        )

axs.scatter(
    [],
    [],
    marker="D",
    color=color_codes[3],
    s=scatter_size,
    label="Doesn't show up on monday",
)

plt.grid(alpha=0.5)
plt.legend()
axs.set_title(title)
axs.set_ylabel(y_label)
fig = plt.gcf()
fig.set_size_inches(fig_size)
